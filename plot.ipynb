# %%
import pandas
import numpy
from matplotlib import pyplot, ticker
pyplot.rcdefaults()

# %%
filename = "dataframe.csv"
data = pandas.read_csv(filename, header=0, index_col=0).T
data.index = pandas.read_csv(filename, header=None, index_col=0).iloc[0].values
data.T.plot(legend=None)
data

# %%
# ファイル読み込み
import tkinter.filedialog
root = tkinter.Tk()
root.withdraw()
root.attributes("-topmost", True)
root.lift()
root.focus_force()
filename = tkinter.filedialog.askopenfilename(filetypes=[("csv", "*.csv")])
if pandas.read_csv(filename).columns[0] == "Unnamed: 0":
	data = pandas.read_csv(filename, header=0, index_col=0).T
	data.index = pandas.read_csv(filename, header=None, index_col=0).iloc[0].values
else:	data = pandas.DataFrame(pandas.read_csv(filename, header=None, index_col=0).squeeze()).T
data.T.plot(legend=None)
data

# %%
# tick
pyplot.rcParams["xtick.bottom"] = True  # 下軸目盛の表示
pyplot.rcParams["xtick.top"] = True  # 上軸目盛の表示
pyplot.rcParams["ytick.left"] = True  # 左軸目盛の表示
pyplot.rcParams["ytick.right"] = True  # 右軸目盛の表示
pyplot.rcParams["xtick.direction"] = "in"  # 縦軸目盛の向き
pyplot.rcParams["ytick.direction"] = "in"  # 横軸目盛の向き
pyplot.rcParams["xtick.major.size"] = 10  # 横軸主目盛の長さ
pyplot.rcParams["ytick.major.size"] = 10  # 縦軸主目盛の長さ
pyplot.rcParams["xtick.minor.size"] = 5  # 横軸副目盛の長さ
pyplot.rcParams["ytick.minor.size"] = 5  # 縦軸副目盛の長さ
# line
pyplot.rcParams["lines.linewidth"] = 2  # 折れ線グラフの太さ
pyplot.rcParams["axes.linewidth"] = 2  # 軸線の太さ
pyplot.rcParams["xtick.major.width"] = 2  # 横軸主目盛の太さ
pyplot.rcParams["ytick.major.width"] = 2  # 縦軸主目盛の太さ
pyplot.rcParams["xtick.minor.width"] = 2  # 横軸副目盛の太さ
pyplot.rcParams["ytick.minor.width"] = 2  # 縦軸副目盛の太さ
# pad
pyplot.rcParams["axes.labelpad"] = 5  # タイトルの軸からの距離
pyplot.rcParams["xtick.major.pad"] = 10  # 横軸目盛の軸からの距離
pyplot.rcParams["ytick.major.pad"] = 10  # 縦軸目盛の軸からの距離
# save
pyplot.rcParams["savefig.format"] = "png"
pyplot.rcParams["savefig.dpi"] = 150
pyplot.rcParams["savefig.transparent"] = False
pyplot.rcParams["savefig.bbox"] = "tight"
# フォント
pyplot.rcParams["font.size"] = "20"  # フォントサイズ
font = 3  # フォント指定
if font == 1: pyplot.rcParams["font.family"] = "Times New Roman"  # セリフフォント
if font == 2: pyplot.rcParams["font.family"] = "Arial"  # サンセリフフォント
if font == 3: pyplot.rcParams["font.family"] = "Meiryo"  # 日本語フォント
print("size =", pyplot.rcParams["font.size"], "\nfont =", pyplot.rcParams["font.family"][0])

# %%
fig = pyplot.figure(figsize=(6, 4))  # 図の大きさ
ax1 = fig.add_axes((0, 0, 1, 1))  # (left, top, width, height)
ax1.set_axisbelow(False)  # True: プロットが軸の上, False: 軸がプロットの上

ax1.plot(data.columns, data.iloc[-1], c="red", label="280 \N{DEGREE SIGN}C")  # 折れ線グラフ
ax1.plot(data.columns, data.iloc[0], c="blue", label="140 \N{DEGREE SIGN}C")  # 折れ線グラフ

# 矢印
buff = pyplot.rcParams["font.size"]
pyplot.rcParams["font.size"] = 18
px, py = 3400, 1.32
ax1.annotate("3400", (px+150, py+0.19))
ax1.annotate("", xy=(px, py), xytext=(px, py+0.16), arrowprops=dict(width=0.8, headwidth=5, headlength=10, color="black"))
pyplot.rcParams["font.size"] = buff

# ax1.scatter(data.columns, data.iloc[0], c="red", s=10, label="legend")  # 散布図
ax1.legend(bbox_to_anchor=(1,0.5), loc="center left", frameon=False)  # 凡例表示
ax1.set_title("PVA", pad=10)  # タイトル表示

ax1.set_xlim(4000, 1000)  # 横軸の範囲
ax1.set_xticks(numpy.arange(1000, 4001, 500))  # 横軸の主目盛
ax1.xaxis.set_minor_locator(ticker.MultipleLocator(100))  # 横軸の副目盛
ax1.set_xlabel("Wavenumber / cm$^{-1}$")  # 横軸のタイトル

ax1.set_ylim(0, 1.7)  # 縦軸の範囲
ax1.set_yticks(numpy.arange(0, 1.71, 0.2))  # 縦軸の主目盛
ax1.yaxis.set_minor_locator(ticker.MultipleLocator(0.05))  # 縦軸の副目盛
ax1.set_ylabel("Absorbance")  # 縦軸のタイトル

# ax2 = ax1.twinx()  # 右軸の設定

pyplot.savefig(filename[:-4] + ".png")  # 画像として保存
pyplot.show()

# %%
width, hight = 8, 5

xmax, xmin = 3700, 3000
xtickmin, xtickmax, xmajor, xminor = 3000, 3701, 100, 20
xlabel = "Wavenumber / cm$^{-1}$"

ymin, ymax = 0, 1.4
ytickmin, ytickmax, ymajor, yminor = 0, 1.41, 0.2, 0.05
ylabel = "Absorbance"

fig = pyplot.figure(figsize=(width, hight))
ax1 = fig.add_axes((0, 0, 1, 1))
ax1.set_xlim(xmax, xmin)
ax1.set_xticks(numpy.arange(xtickmin, xtickmax, xmajor))
ax1.xaxis.set_minor_locator(ticker.MultipleLocator(xminor))
ax1.set_xlabel(xlabel)
ax1.set_ylim(ymin, ymax)
ax1.set_yticks(numpy.arange(ytickmin, ytickmax, ymajor))
ax1.yaxis.set_minor_locator(ticker.MultipleLocator(yminor))
ax1.set_ylabel(ylabel)

x = data.columns

i = 1
y = data.iloc[i]
pyplot.plot(x, y, color="blue", label=str(data.index[i]) + u" \N{DEGREE SIGN}C")

i = 6
y = data.iloc[i]
pyplot.plot(x, y, color="gray", label=str(data.index[i]) + u" \N{DEGREE SIGN}C")

i = -1
y = data.iloc[i]
pyplot.plot(x, y, color="red", label=str(data.index[i]) + u" \N{DEGREE SIGN}C")

pyplot.legend(frameon=False)
pyplot.savefig(filename[:-4] + ".png")
pyplot.show()

# %% [markdown]
# https://matplotlib.org/stable/gallery/color/named_colors.html

# %%
width, hight = 8, 4

xmax, xmin = 3700, 3000
xtickmin, xtickmax, xmajor, xminor = 3000, 3701, 100, 20
xlabel = "Wavenumber / cm$^{-1}$"

ymin, ymax = 0, 1.4
ytickmin, ytickmax, ymajor, yminor = 0, 1.41, 0.2, 0.05
ylabel = "Absorbance"

fig = pyplot.figure(figsize=(width, hight))
ax1 = fig.add_axes((0, 1, 1, 1))
ax1.xaxis.set_ticklabels([])
ax1.set_xlim(xmax, xmin)
ax1.set_xticks(numpy.arange(xtickmin, xtickmax, xmajor))
ax1.xaxis.set_minor_locator(ticker.MultipleLocator(xminor))
ax1.set_ylim(ymin, ymax)
ax1.set_yticks(numpy.arange(ytickmin, ytickmax, ymajor))
ax1.yaxis.set_minor_locator(ticker.MultipleLocator(yminor))
ax1.set_ylabel(ylabel)

x = data.columns

i = 6
y = data.iloc[i]
pyplot.plot(x, y, color="red", label=str(data.index[i]) + u" \N{DEGREE SIGN}C")
pyplot.legend(frameon=False)

ymin, ymax = 0, 1.4
ytickmin, ytickmax, ymajor, yminor = 0, 1.4, 0.2, 0.05
ylabel = "Absorbance"

ax2 = fig.add_axes((0, 0, 1, 1))
ax2.set_xlim(xmax, xmin)
ax2.set_xticks(numpy.arange(xtickmin, xtickmax, xmajor))
ax2.xaxis.set_minor_locator(ticker.MultipleLocator(xminor))
ax2.set_xlabel(xlabel)
ax2.set_ylim(ymin, ymax)
ax2.set_yticks(numpy.arange(ytickmin, ytickmax, ymajor))
ax2.yaxis.set_minor_locator(ticker.MultipleLocator(yminor))
ax2.set_ylabel(ylabel)

i = 0
y = data.iloc[i]
pyplot.plot(x, y, color="blue", label=str(data.index[i]) + u" \N{DEGREE SIGN}C")

pyplot.legend(frameon=False)
pyplot.savefig(filename[:-4] + ".png")
pyplot.show()

# %%
width, hight = 8, 5

xmax, xmin = 3000, 2800
xtickmin, xtickmax, xmajor, xminor = 2800, 3001, 40, 10
xlabel = "Wavenumber / cm$^{-1}$"

ymin, ymax = 0, 1.1
ytickmin, ytickmax, ymajor, yminor = 0, 1.11, 0.2, 0.05
ylabel = "Absorbance"

fig = pyplot.figure(figsize=(width, hight))
ax1 = fig.add_axes((0, 0, 1, 1))
ax1.set_xlim(xmax, xmin)
ax1.set_xticks(numpy.arange(xtickmin, xtickmax, xmajor))
ax1.xaxis.set_minor_locator(ticker.MultipleLocator(xminor))
ax1.set_xlabel(xlabel)
ax1.set_ylim(ymin, ymax)
ax1.set_yticks(numpy.arange(ytickmin, ytickmax, ymajor))
ax1.yaxis.set_minor_locator(ticker.MultipleLocator(yminor))
ax1.set_ylabel(ylabel)

x = data.columns

i = 0
y = data.iloc[i]
pyplot.scatter(x, y, color="blue", label=str(data.index[i]) + u" \N{DEGREE SIGN}C")

i = 6
y = data.iloc[i]
pyplot.scatter(x, y, color="red", label=str(data.index[i]) + u" \N{DEGREE SIGN}C")

pyplot.legend(frameon=False)
pyplot.savefig(filename[:-4] + ".png")
pyplot.show()

# %%
width, hight = 8, 5

xmax, xmin = 1900, 1000
xtickmin, xtickmax, xmajor, xminor = 1000, 1901, 100, 20
label = "Wavenumber / cm$^{-1}$"

ymin, ymax = 0, 1.3
ytickmin, ytickmax, ymajor, yminor = 0, 1.31, 0.2, 0.05
ylabel = "Absorbance"

fig = pyplot.figure(figsize=(width, hight))
ax1 = fig.add_axes((0, 0, 1, 1))
ax1.set_xlim(xmax, xmin)
ax1.set_xticks(numpy.arange(xtickmin, xtickmax, xmajor))
ax1.xaxis.set_minor_locator(ticker.MultipleLocator(xminor))
ax1.set_xlabel(xlabel)
ax1.set_ylim(ymin, ymax)
ax1.set_yticks(numpy.arange(ytickmin, ytickmax, ymajor))
ax1.yaxis.set_minor_locator(ticker.MultipleLocator(yminor))
ax1.set_ylabel(ylabel)

pyplot.rcParams["lines.linewidth"] = 0.5
cmap = pyplot.get_cmap("coolwarm")
for i in range(len(data)):
    ind = i / len(data)
    ax1.plot(data.columns, data.iloc[i], color=cmap(ind))

pyplot.rcParams["lines.linewidth"] = 2
ax1.plot(data.columns, data.iloc[0], color="blue", label=str(data.index[0]) + u" \N{DEGREE SIGN}C")
ax1.plot(data.columns, data.iloc[-1], color="red", label=str(data.index[-1]) + u" \N{DEGREE SIGN}C")

ax1.legend(frameon=False)
pyplot.savefig(filename[:-4] + ".png")
pyplot.show()

# %% [markdown]
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
width, hight = 8, 5

xmax, xmin = 3700, 3000
xtickmin, xtickmax, xmajor, xminor = 3000, 3701, 100, 20
xlabel = "Wavenumber / cm$^{-1}$"

ymin, ymax = 0, 1.4
ytickmin, ytickmax, ymajor, yminor = 0, 1.41, 0.2, 0.05
ylabel = "Absorbance"

fig = pyplot.figure(figsize=(width, hight))
ax1 = fig.add_axes((0, 0, 1, 1))
ax1.set_xlim(xmax, xmin)
ax1.set_xticks(numpy.arange(xtickmin, xtickmax, xmajor))
ax1.xaxis.set_minor_locator(ticker.MultipleLocator(xminor))
ax1.set_xlabel(xlabel)
ax1.set_ylim(ymin, ymax)
ax1.set_yticks(numpy.arange(ytickmin, ytickmax, ymajor))
ax1.yaxis.set_minor_locator(ticker.MultipleLocator(yminor))
ax1.set_ylabel(ylabel)

pyplot.rcParams["lines.linewidth"] = 0.5
for i in range(len(data)):
    ax1.plot(data.columns, data.iloc[i], color="gray")

pyplot.rcParams["lines.linewidth"] = 2
ax1.plot(data.columns, data.iloc[0], color="blue", label=str(data.index[0]) + u" \N{DEGREE SIGN}C")
ax1.plot(data.columns, data.iloc[-1], color="red", label=str(data.index[-1]) + u" \N{DEGREE SIGN}C")

ax1.legend(frameon=False)
pyplot.savefig(filename[:-4] + ".png")
pyplot.show()
